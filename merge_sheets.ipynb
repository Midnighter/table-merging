# %%
from glob import glob

# %%
import pandas as pd

# %%
files = sorted(glob("./*.xls*"))

# %%
for (i, n) in enumerate(files):
    print("{0:>3d} - {1}".format(i, n))
# Out:
#   0 - ./00_SocialCollective_Vernetzungsplattformen_151220.xls
#   1 - ./Hamburger Flüchtlings- und Willkommensinitiativen.xlsx
#   2 - ./InfoCompass – Content (1).xlsx
#   3 - ./InfoCompass – Content (2).xlsx
#   4 - ./InfoCompass – Content (3).xlsx
#   5 - ./InfoCompass – Content.xlsx
#   6 - ./MetaBrain_DB_TUB.xlsx
#   7 - ./Online Information Services.xlsx
#   8 - ./Refugee Crisis FB Groups & Refugee Maps Data.xlsx
#   9 - ./Refugee Initiativen - Liste Wefugee.xlsx
#  10 - ./refugeeboard_Frankfurt.xlsx
#  11 - ./refugees.sahana.io_Organizations.xls

# %%
social_collective = pd.read_excel("00_SocialCollective_Vernetzungsplattformen_151220.xls")

# %%
hamburg = pd.read_excel("Hamburger Flüchtlings- und Willkommensinitiativen.xlsx", skiprows=19)

# %%
tub = pd.read_excel("MetaBrain_DB_TUB.xlsx", sheetname="DB")

# %%
ois = dict()
with pd.ExcelFile("Online Information Services.xlsx") as xls:
    ois_names = xls.sheet_names
    for name in ois_names:
        ois[name] = pd.read_excel(xls, name)

# %% [markdown]
# Skip Facebook groups for now (`files[4]`).

# %%
wefugee = dict()
with pd.ExcelFile("Refugee Initiativen - Liste Wefugee.xlsx") as xls:
    wefugee_names = xls.sheet_names
    for name in wefugee_names:
        wefugee[name] = pd.read_excel(xls, name)

# %%
refugeeboard = pd.read_excel("refugeeboard_Frankfurt.xlsx")

# %%
sahana = pd.read_excel("refugees.sahana.io_Organizations.xls")

# %% [markdown]
# Compare name and some kind of URL between all projects.

# %%
def simple_clean(df, header=["name", "url"]):
    df.columns = header
    return df[-(df[header[0]].isnull() | df[header[1]].isnull())]

# %%
data = list()
tmp = simple_clean(social_collective[["Projekt", "Webseite"]])
tmp["source"] = "social collective"
data.append(tmp)
tmp = simple_clean(tub[["title", "url"]])
tmp["source"] = "TU Berlin"
data.append(tmp)
for name in ois_names:
    tmp = simple_clean(ois[name][["Service Name", "Link"]])
    tmp["source"] = "OIS {}".format(name)
    data.append(tmp)
for name in wefugee_names:
    if name == "Ansprechpartner":
        continue
    tmp = simple_clean(wefugee[name][["Organization", "Link"]])
    tmp["source"] = "Wefugee {}".format(name)
    data.append(tmp)
tmp = simple_clean(refugeeboard[["name", "webseite"]])
tmp["source"] = "refugeeboard"
data.append(tmp)
tmp = simple_clean(sahana[["Name", "Website"]])
tmp["source"] = "Sahana"
data.append(tmp)

# %%
merge = pd.concat(data, ignore_index=True)

# %%
len(merge)
# Out:
# 1001

# %%
merge.sort_values(["url", "source"], inplace=True)

# %%
duplicated_url = merge.duplicated(subset="url", keep=False)

# %%
duplicated_url.sum()
# Out:
# 425

# %%
merge[duplicated_url]
# Out:
#                                                   name  \
# 92               Adelante Antifaschistische Linke Bonn
# 662              Adelante Antifaschistische Linke Bonn
# 105                               alle-helfen-jetzt.de
# 13                                alle-helfen-jetzt.de
# 106                                    Allende 2 hilft
# 534                                    Allende 2 hilft
# 111                                  Apps for Refugees
# 19                                  Apps for Refugees
# 117                                 Arriving in Berlin
# 3                                   Arriving in Berlin
# 126                  Ausbildung statt Abschiebung e.V.
# 655                  Ausbildung statt Abschiebung e.V.
# 283                                Asyl in Brandenburg
# 58                          Initiativen in Brandenburg
# 130                                         babelverse
# 79                                          babelverse
# 159             Bündnis gegen Lager Berlin-Brandenburg
# 558             Bündnis gegen Lager Berlin-Brandenburg
# 149  Bonner Institut für Migrationsforschung und In...
# 677  Bonner Institut für Migrationsforschung und In...
# 150                             Bonner Jugend Bewegung
# 659                             Bonner Jugend Bewegung
# 171             Caritasverband für die Stadt Bonn e.V.
# 663             Caritasverband für die Stadt Bonn e.V.
# 175                                          Charitree
# 71                                           Charitree
# 189        Deutsches Rotes Kreuz Bonn Flüchtlingshilfe
# 664                              Deutsches Rotes Kreuz
# 229                                    Frankfurt hilft
# 49                                     Frankfurt hilft
# ..                                                 ...
# 377                              Refugee Volunteer Map
# 26                               Refugee Volunteer Map
# 258                                          Help Here
# 34                                           Help Here
# 272               Humboldt-Universität Gasthörerschaft
# 582                               Humboldt-Universität
# 271                                          Humanwire
# 75                                           Humanwire
# 219                               Flüchtlingshilfe NRW
# 46                                Flüchtlingshilfe NRW
# 331                                          Movements
# 60                                           Movements
# 407                      Schwulenberatung Berlin gGmbH
# 613                      Schwulenberatung Berlin gGmbH
# 439                   Volkshochschule (VHS) Stadt Bonn
# 681                   Volkshochschule (VHS) Stadt Bonn
# 108                         Amnesty International Bonn
# 656                         Amnesty International Bonn
# 123                                  Asylstrike Berlin
# 540                                  Asylstrike Berlin
# 156  Bundesfachverband Unbegleitete Minderjährige F...
# 553  Bundesfachverband Unbegleitete Minderjährige F...
# 157  Bundesweite Arbeitsgemeinschaft der Psychosozi...
# 554  Bundesweite Arbeitsgemeinschaft der Psychosozi...
# 127                                  Ausländeramt Bonn
# 666                                       Ausländeramt
# 332                                          Multitude
# 598                                     Multitude e.V.
# 375                       Refugee Struggle for Freedom
# 610                       Refugee Struggle for Freedom
#
#                                                    url             source
# 92                        http://adelante.blogsport.de          TU Berlin
# 662                       http://adelante.blogsport.de       Wefugee Bonn
# 105                        http://alle-helfen-jetzt.de          TU Berlin
# 13                         http://alle-helfen-jetzt.de  social collective
# 106                            http://allende2hilft.de          TU Berlin
# 534                            http://allende2hilft.de    Wefugee Berlin
# 111                         http://appsforrefugees.com          TU Berlin
# 19                          http://appsforrefugees.com  social collective
# 117                      http://arriving-in-berlin.de/          TU Berlin
# 3                        http://arriving-in-berlin.de/  social collective
# 126                                http://asa-bonn.org          TU Berlin
# 655                                http://asa-bonn.org       Wefugee Bonn
# 283  http://asyl-brandenburg.de/asyl-in-brandenburg...          TU Berlin
# 58   http://asyl-brandenburg.de/asyl-in-brandenburg...  social collective
# 130                              http://babelverse.com          TU Berlin
# 79                               http://babelverse.com  social collective
# 159                          http://bglbb.blogsport.de          TU Berlin
# 558                          http://bglbb.blogsport.de    Wefugee Berlin
# 149                                   http://bimev.de/          TU Berlin
# 677                                   http://bimev.de/       Wefugee Bonn
# 150                            http://bjb.blogsport.de          TU Berlin
# 659                            http://bjb.blogsport.de       Wefugee Bonn
# 171  http://caritas.erzbistum-koeln.de/bonn-cv/bera...          TU Berlin
# 663  http://caritas.erzbistum-koeln.de/bonn-cv/bera...       Wefugee Bonn
# 175                 http://charitree-berlin.jimdo.com/          TU Berlin
# 71                  http://charitree-berlin.jimdo.com/  social collective
# 189  http://drkbn.drkcms.de/angebote/migration-und-...          TU Berlin
# 664  http://drkbn.drkcms.de/angebote/migration-und-...       Wefugee Bonn
# 229                         http://frankfurt-hilft.de/          TU Berlin
# 49                          http://frankfurt-hilft.de/  social collective
# ..                                                 ...                ...
# 377  https://www.google.com/maps/d/viewer?mid=zddfR...          TU Berlin
# 26   https://www.google.com/maps/d/viewer?mid=zddfR...  social collective
# 258                            https://www.helphere.de          TU Berlin
# 34                             https://www.helphere.de  social collective
# 272  https://www.hu-berlin.de/de/pr/pressemitteilun...          TU Berlin
# 582  https://www.hu-berlin.de/de/pr/pressemitteilun...    Wefugee Berlin
# 271                         https://www.humanwire.org/          TU Berlin
# 75                          https://www.humanwire.org/  social collective
# 219                         https://www.ich-helfe.nrw/          TU Berlin
# 46                          https://www.ich-helfe.nrw/  social collective
# 331                          https://www.movements.org          TU Berlin
# 60                           https://www.movements.org  social collective
# 407  https://www.schwulenberatungberlin.de/wir-helf...          TU Berlin
# 613  https://www.schwulenberatungberlin.de/wir-helf...    Wefugee Berlin
# 439  https://www.vhs-bonn.de/programm-anmeldung/deu...          TU Berlin
# 681  https://www.vhs-bonn.de/programm-anmeldung/deu...       Wefugee Bonn
# 108                                www.amnesty-bonn.de          TU Berlin
# 656                                www.amnesty-bonn.de       Wefugee Bonn
# 123                 www.asylstrikeberlin.wordpress.com          TU Berlin
# 540                 www.asylstrikeberlin.wordpress.com    Wefugee Berlin
# 156                                       www.b-umf.de          TU Berlin
# 553                                       www.b-umf.de    Wefugee Berlin
# 157                               www.baff-zentren.org          TU Berlin
# 554                               www.baff-zentren.org    Wefugee Berlin
# 127  www.bonn.de/rat_verwaltung_buergerdienste/buer...          TU Berlin
# 666  www.bonn.de/rat_verwaltung_buergerdienste/buer...       Wefugee Bonn
# 332                            www.multitude-berlin.de          TU Berlin
# 598                            www.multitude-berlin.de    Wefugee Berlin
# 375                            www.refugeestruggle.org          TU Berlin
# 610                            www.refugeestruggle.org    Wefugee Berlin
#
# [425 rows x 3 columns]
